# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
df = pd.read_csv("dataset/superstore_sales.csv")

df.head()
# Out:
#    Order ID  Order Date  Customer Name      Segment Region          State  \
# 0  ORD00001  2023-05-02  Customer_1466     Consumer  North          Delhi
# 1  ORD00002  2024-10-25  Customer_9322  Home Office  South      Karnataka
# 2  ORD00003  2024-01-21  Customer_6311     Consumer  North  Uttar Pradesh
# 3  ORD00004  2023-09-10  Customer_9666     Consumer  South      Karnataka
# 4  ORD00005  2025-04-11  Customer_2528  Home Office  South      Telangana
#
#           Category Sub-Category    Sales  Quantity  Discount  Profit
# 0  Office Supplies      Stapler  1935.25         8      0.20  308.12
# 1  Office Supplies          Pen   589.88         8      0.20   94.55
# 2       Technology       Laptop   200.86         2      0.15   51.15
# 3  Office Supplies       Marker  4961.84         1      0.15  857.97
# 4       Technology      Monitor  3098.08         3      0.15  460.25

# %%
df = pd.read_csv("dataset/superstore_sales.csv")

# %%
df
# Out:
#        Order ID  Order Date  Customer Name      Segment Region  \
# 0      ORD00001  2023-05-02  Customer_1466     Consumer  North
# 1      ORD00002  2024-10-25  Customer_9322  Home Office  South
# 2      ORD00003  2024-01-21  Customer_6311     Consumer  North
# 3      ORD00004  2023-09-10  Customer_9666     Consumer  South
# 4      ORD00005  2025-04-11  Customer_2528  Home Office  South
# ...         ...         ...            ...          ...    ...
# 11995  ORD11996  2023-12-15  Customer_1221    Corporate   West
# 11996  ORD11997  2024-03-31  Customer_8022     Consumer  North
# 11997  ORD11998  2024-01-09  Customer_8981  Home Office   West
# 11998  ORD11999  2025-04-17  Customer_8619  Home Office   West
# 11999  ORD12000  2024-08-29  Customer_7473  Home Office  South
#
#                 State         Category Sub-Category    Sales  Quantity  \
# 0               Delhi  Office Supplies      Stapler  1935.25         8
# 1           Karnataka  Office Supplies          Pen   589.88         8
# 2       Uttar Pradesh       Technology       Laptop   200.86         2
# 3           Karnataka  Office Supplies       Marker  4961.84         1
# 4           Telangana       Technology      Monitor  3098.08         3
# ...               ...              ...          ...      ...       ...
# 11995  Madhya Pradesh       Technology        Mouse  1162.69         9
# 11996   Uttar Pradesh  Office Supplies       Marker  2839.58         4
# 11997       Rajasthan        Furniture    Bookshelf   763.01         6
# 11998     Maharashtra  Office Supplies          Pen   525.83         2
# 11999       Karnataka        Furniture         Desk   118.28         3
#
#        Discount  Profit
# 0          0.20  308.12
# 1          0.20   94.55
# 2          0.15   51.15
# 3          0.15  857.97
# 4          0.15  460.25
# ...         ...     ...
# 11995      0.05  305.05
# 11996      0.05  443.94
# 11997      0.05   59.86
# 11998      0.10  109.30
# 11999      0.15   16.87
#
# [12000 rows x 12 columns]

# %%
df.head()
# Out:
#    Order ID  Order Date  Customer Name      Segment Region          State  \
# 0  ORD00001  2023-05-02  Customer_1466     Consumer  North          Delhi
# 1  ORD00002  2024-10-25  Customer_9322  Home Office  South      Karnataka
# 2  ORD00003  2024-01-21  Customer_6311     Consumer  North  Uttar Pradesh
# 3  ORD00004  2023-09-10  Customer_9666     Consumer  South      Karnataka
# 4  ORD00005  2025-04-11  Customer_2528  Home Office  South      Telangana
#
#           Category Sub-Category    Sales  Quantity  Discount  Profit
# 0  Office Supplies      Stapler  1935.25         8      0.20  308.12
# 1  Office Supplies          Pen   589.88         8      0.20   94.55
# 2       Technology       Laptop   200.86         2      0.15   51.15
# 3  Office Supplies       Marker  4961.84         1      0.15  857.97
# 4       Technology      Monitor  3098.08         3      0.15  460.25

# %%
df.shape
# Out:
# (12000, 12)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'Segment', 'Region', 'State',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       12000 non-null  object
#  1   Order Date     12000 non-null  object
#  2   Customer Name  12000 non-null  object
#  3   Segment        12000 non-null  object
#  4   Region         12000 non-null  object
#  5   State          12000 non-null  object
#  6   Category       12000 non-null  object
#  7   Sub-Category   12000 non-null  object
#  8   Sales          12000 non-null  float64
#  9   Quantity       12000 non-null  int64
#  10  Discount       12000 non-null  float64
#  11  Profit         12000 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#               Sales      Quantity      Discount        Profit
# count  12000.000000  12000.000000  12000.000000  12000.000000
# mean    2540.241745      4.978583      0.100125    394.939982
# std     1421.236122      2.569178      0.071008    308.733959
# min      100.030000      1.000000      0.000000      1.890000
# 25%     1312.287500      3.000000      0.050000    141.460000
# 50%     2536.265000      5.000000      0.100000    317.310000
# 75%     3769.375000      7.000000      0.150000    586.897500
# max     4999.510000      9.000000      0.200000   1497.630000

# %%
df.dtypes
# Out:
# Order ID          object
# Order Date        object
# Customer Name     object
# Segment           object
# Region            object
# State             object
# Category          object
# Sub-Category      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df["Category"].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Category
# Furniture          4037
# Office Supplies    4000
# Technology         3963
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Segment          0
# Region           0
# State            0
# Category         0
# Sub-Category     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#        Order ID  Order Date  Customer Name      Segment Region  \
# 0      ORD00001  2023-05-02  Customer_1466     Consumer  North
# 1      ORD00002  2024-10-25  Customer_9322  Home Office  South
# 2      ORD00003  2024-01-21  Customer_6311     Consumer  North
# 3      ORD00004  2023-09-10  Customer_9666     Consumer  South
# 4      ORD00005  2025-04-11  Customer_2528  Home Office  South
# ...         ...         ...            ...          ...    ...
# 11995  ORD11996  2023-12-15  Customer_1221    Corporate   West
# 11996  ORD11997  2024-03-31  Customer_8022     Consumer  North
# 11997  ORD11998  2024-01-09  Customer_8981  Home Office   West
# 11998  ORD11999  2025-04-17  Customer_8619  Home Office   West
# 11999  ORD12000  2024-08-29  Customer_7473  Home Office  South
#
#                 State         Category Sub-Category    Sales  Quantity  \
# 0               Delhi  Office Supplies      Stapler  1935.25         8
# 1           Karnataka  Office Supplies          Pen   589.88         8
# 2       Uttar Pradesh       Technology       Laptop   200.86         2
# 3           Karnataka  Office Supplies       Marker  4961.84         1
# 4           Telangana       Technology      Monitor  3098.08         3
# ...               ...              ...          ...      ...       ...
# 11995  Madhya Pradesh       Technology        Mouse  1162.69         9
# 11996   Uttar Pradesh  Office Supplies       Marker  2839.58         4
# 11997       Rajasthan        Furniture    Bookshelf   763.01         6
# 11998     Maharashtra  Office Supplies          Pen   525.83         2
# 11999       Karnataka        Furniture         Desk   118.28         3
#
#        Discount  Profit
# 0          0.20  308.12
# 1          0.20   94.55
# 2          0.15   51.15
# 3          0.15  857.97
# 4          0.15  460.25
# ...         ...     ...
# 11995      0.05  305.05
# 11996      0.05  443.94
# 11997      0.05   59.86
# 11998      0.10  109.30
# 11999      0.15   16.87
#
# [12000 rows x 12 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Order ID          object
# Order Date        object
# Customer Name     object
# Segment           object
# Region            object
# State             object
# Category          object
# Sub-Category      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Customer Name            object
# Segment                  object
# Region                   object
# State                    object
# Category                 object
# Sub-Category             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       12000 non-null  object
#  1   Order Date     12000 non-null  datetime64[ns]
#  2   Customer Name  12000 non-null  object
#  3   Segment        12000 non-null  object
#  4   Region         12000 non-null  object
#  5   State          12000 non-null  object
#  6   Category       12000 non-null  object
#  7   Sub-Category   12000 non-null  object
#  8   Sales          12000 non-null  float64
#  9   Quantity       12000 non-null  int64
#  10  Discount       12000 non-null  float64
#  11  Profit         12000 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()/ len(df) *100
# Out:
# Order ID         0.0
# Order Date       0.0
# Customer Name    0.0
# Segment          0.0
# Region           0.0
# State            0.0
# Category         0.0
# Sub-Category     0.0
# Sales            0.0
# Quantity         0.0
# Discount         0.0
# Profit           0.0
# dtype: float64

# %%
numeric_columns = df.select_dtypes(include=["int64", "float64"])

numeric_columns.head()
# Out:
#      Sales  Quantity  Discount  Profit
# 0  1935.25         8      0.20  308.12
# 1   589.88         8      0.20   94.55
# 2   200.86         2      0.15   51.15
# 3  4961.84         1      0.15  857.97
# 4  3098.08         3      0.15  460.25

# %%
categorical_columns = df.select_dtypes(include=["object"])

categorical_columns.head()
# Out:
#    Order ID  Customer Name      Segment Region          State  \
# 0  ORD00001  Customer_1466     Consumer  North          Delhi
# 1  ORD00002  Customer_9322  Home Office  South      Karnataka
# 2  ORD00003  Customer_6311     Consumer  North  Uttar Pradesh
# 3  ORD00004  Customer_9666     Consumer  South      Karnataka
# 4  ORD00005  Customer_2528  Home Office  South      Telangana
#
#           Category Sub-Category
# 0  Office Supplies      Stapler
# 1  Office Supplies          Pen
# 2       Technology       Laptop
# 3  Office Supplies       Marker
# 4       Technology      Monitor

# %%
df.to_csv("dataset/clean_sales_data.csv", index=False)

# %%
df
# Out:
#        Order ID Order Date  Customer Name      Segment Region           State  \
# 0      ORD00001 2023-05-02  Customer_1466     Consumer  North           Delhi
# 1      ORD00002 2024-10-25  Customer_9322  Home Office  South       Karnataka
# 2      ORD00003 2024-01-21  Customer_6311     Consumer  North   Uttar Pradesh
# 3      ORD00004 2023-09-10  Customer_9666     Consumer  South       Karnataka
# 4      ORD00005 2025-04-11  Customer_2528  Home Office  South       Telangana
# ...         ...        ...            ...          ...    ...             ...
# 11995  ORD11996 2023-12-15  Customer_1221    Corporate   West  Madhya Pradesh
# 11996  ORD11997 2024-03-31  Customer_8022     Consumer  North   Uttar Pradesh
# 11997  ORD11998 2024-01-09  Customer_8981  Home Office   West       Rajasthan
# 11998  ORD11999 2025-04-17  Customer_8619  Home Office   West     Maharashtra
# 11999  ORD12000 2024-08-29  Customer_7473  Home Office  South       Karnataka
#
#               Category Sub-Category    Sales  Quantity  Discount  Profit
# 0      Office Supplies      Stapler  1935.25         8      0.20  308.12
# 1      Office Supplies          Pen   589.88         8      0.20   94.55
# 2           Technology       Laptop   200.86         2      0.15   51.15
# 3      Office Supplies       Marker  4961.84         1      0.15  857.97
# 4           Technology      Monitor  3098.08         3      0.15  460.25
# ...                ...          ...      ...       ...       ...     ...
# 11995       Technology        Mouse  1162.69         9      0.05  305.05
# 11996  Office Supplies       Marker  2839.58         4      0.05  443.94
# 11997        Furniture    Bookshelf   763.01         6      0.05   59.86
# 11998  Office Supplies          Pen   525.83         2      0.10  109.30
# 11999        Furniture         Desk   118.28         3      0.15   16.87
#
# [12000 rows x 12 columns]

# %%
total_sales = df["Sales"].sum()

print("Total Sales =", total_sales)
# Out:
# Total Sales = 30482900.94

# %%
total_profit = df["Profit"].sum()

print("Total Profit =", total_profit)
# Out:
# Total Profit = 4739279.789999999

# %%
total_orders = df["Order ID"].nunique()

print("Total Orders =", total_orders)
# Out:
# Total Orders = 12000

# %%
total_customers = df["Customer Name"].nunique()

print("Total Customers =", total_customers)
# Out:
# Total Customers = 6574

# %%
average_sales = df["Sales"].mean()

print("Average Sales =", average_sales)
# Out:
# Average Sales = 2540.2417450000003

# %%
region_sales = df.groupby("Region")["Sales"].sum()

print(region_sales)
# Out:
# Region
# East     7490978.67
# North    7464061.30
# South    7610052.01
# West     7917808.96
# Name: Sales, dtype: float64

# %%
state_sales = df.groupby("State")["Sales"].sum().sort_values(ascending=False)

print(state_sales)
# Out:
# State
# Maharashtra       2072476.50
# Madhya Pradesh    2000351.29
# Gujarat           1976230.39
# Tamil Nadu        1955118.24
# Punjab            1918047.41
# Kerala            1915811.71
# Telangana         1910037.65
# Assam             1909607.67
# Odisha            1907645.11
# Uttar Pradesh     1889215.10
# Bihar             1872233.86
# Rajasthan         1868750.78
# Delhi             1868294.39
# Karnataka         1829084.41
# West Bengal       1801492.03
# Haryana           1788504.40
# Name: Sales, dtype: float64

# %%
category_sales = df.groupby("Category")["Sales"].sum()

print(category_sales)
# Out:
# Category
# Furniture          10361856.66
# Office Supplies    10166669.54
# Technology          9954374.74
# Name: Sales, dtype: float64

# %%
subcategory_sales = df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False)

print(subcategory_sales)
# Out:
# Sub-Category
# Sofa         2168809.92
# Desk         2102113.34
# Chair        2097680.76
# Stapler      2085135.42
# File         2065475.49
# Monitor      2056182.31
# Table        2035453.46
# Pen          2008762.36
# Marker       2005088.49
# Notebook     2002207.78
# Mouse        2000749.54
# Keyboard     1994433.35
# Printer      1993494.37
# Bookshelf    1957799.18
# Laptop       1909515.17
# Name: Sales, dtype: float64

# %%
top_customers = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)

print(top_customers)
# Out:
# Customer Name
# Customer_3446    23881.26
# Customer_7999    22548.01
# Customer_8546    22296.95
# Customer_8097    22001.21
# Customer_5723    21149.97
# Customer_3985    20839.82
# Customer_6785    20391.12
# Customer_7967    19752.49
# Customer_9219    19311.09
# Customer_7026    19251.24
# Name: Sales, dtype: float64

# %%
top_products = df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False).head(10)

print(top_products)
# Out:
# Sub-Category
# Sofa        2168809.92
# Desk        2102113.34
# Chair       2097680.76
# Stapler     2085135.42
# File        2065475.49
# Monitor     2056182.31
# Table       2035453.46
# Pen         2008762.36
# Marker      2005088.49
# Notebook    2002207.78
# Name: Sales, dtype: float64

# %%
profit_category = df.groupby("Category")["Profit"].sum()

print(profit_category)
# Out:
# Category
# Furniture          1618674.50
# Office Supplies    1585213.96
# Technology         1535391.33
# Name: Profit, dtype: float64

# %%
df["Month"] = df["Order Date"].dt.month_name()

monthly_sales = df.groupby("Month")["Sales"].sum()

print(monthly_sales)
# Out:
# Month
# April        2943890.27
# August       2195136.80
# December     2001315.46
# February     2930268.27
# January      3176417.23
# July         2142905.43
# June         2660093.13
# March        3191033.03
# May          3275551.54
# November     1889412.27
# October      2080369.40
# September    1996508.11
# Name: Sales, dtype: float64

# %%
df["Year"] = df["Order Date"].dt.year

yearly_sales = df.groupby("Year")["Sales"].sum()

print(yearly_sales)
# Out:
# Year
# 2023    12605068.65
# 2024    12228915.65
# 2025     5648916.64
# Name: Sales, dtype: float64

# %%
summary = df[["Sales", "Profit", "Quantity", "Discount"]].describe()

print(summary)
# Out:
#               Sales        Profit      Quantity      Discount
# count  12000.000000  12000.000000  12000.000000  12000.000000
# mean    2540.241745    394.939982      4.978583      0.100125
# std     1421.236122    308.733959      2.569178      0.071008
# min      100.030000      1.890000      1.000000      0.000000
# 25%     1312.287500    141.460000      3.000000      0.050000
# 50%     2536.265000    317.310000      5.000000      0.100000
# 75%     3769.375000    586.897500      7.000000      0.150000
# max     4999.510000   1497.630000      9.000000      0.200000

# %%
import matplotlib.pyplot as plt

# %%
category_sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(8,5))
plt.bar(category_sales.index, category_sales.values)
plt.title("Category-wise Sales")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %%
region_profit = df.groupby("Region")["Profit"].sum()

plt.figure(figsize=(8,5))
plt.bar(region_profit.index, region_profit.values)
plt.title("Region-wise Profit")
plt.xlabel("Region")
plt.ylabel("Profit")
plt.show()

# %%
df["Month"] = df["Order Date"].dt.month_name()

monthly_sales = df.groupby("Month")["Sales"].sum()

plt.figure(figsize=(10,5))
plt.plot(monthly_sales.index, monthly_sales.values, marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Sales"], bins=20)
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Profit"], bins=20)
plt.title("Profit Distribution")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(7,7))
plt.pie(
    category_sales.values,
    labels=category_sales.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Category-wise Sales")
plt.show()

# %%
state_sales = df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(state_sales.index, state_sales.values)
plt.title("Top 10 States by Sales")
plt.xlabel("State")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
top_customers = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top_customers.index, top_customers.values)
plt.title("Top 10 Customers")
plt.xlabel("Customer")
plt.ylabel("Sales")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["Sales"], df["Profit"])
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
print(df[["Sales","Profit","Quantity","Discount"]].corr())
# Out:
#              Sales    Profit  Quantity  Discount
# Sales     1.000000  0.723558  0.014025  0.006109
# Profit    0.723558  1.000000  0.010322 -0.110047
# Quantity  0.014025  0.010322  1.000000  0.008260
# Discount  0.006109 -0.110047  0.008260  1.000000

# %%
total_sales = df["Sales"].sum()

print("Total Sales: ₹", round(total_sales, 2))
# Out:
# Total Sales: ₹ 30482900.94

# %%
total_profit = df["Profit"].sum()

print("Total Profit: ₹", round(total_profit, 2))
# Out:
# Total Profit: ₹ 4739279.79

# %%
total_orders = df["Order ID"].nunique()

print("Total Orders:", total_orders)
# Out:
# Total Orders: 12000

# %%
average_order = df["Sales"].mean()

print("Average Order Value: ₹", round(average_order, 2))
# Out:
# Average Order Value: ₹ 2540.24

# %%
profit_margin = (total_profit / total_sales) * 100

print("Profit Margin:", round(profit_margin, 2), "%")
# Out:
# Profit Margin: 15.55 %

# %%
top_products = (
    df.groupby("Sub-Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(top_products)
# Out:
# Sub-Category
# Sofa        2168809.92
# Desk        2102113.34
# Chair       2097680.76
# Stapler     2085135.42
# File        2065475.49
# Monitor     2056182.31
# Table       2035453.46
# Pen         2008762.36
# Marker      2005088.49
# Notebook    2002207.78
# Name: Sales, dtype: float64

# %%
top_profit_products = (
    df.groupby("Sub-Category")["Profit"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(top_profit_products)
# Out:
# Sub-Category
# Sofa         336104.12
# Stapler      330826.72
# Chair        330051.30
# Desk         326077.88
# File         325139.86
# Table        314666.76
# Keyboard     312987.99
# Marker       312031.53
# Bookshelf    311774.44
# Monitor      311390.28
# Name: Profit, dtype: float64

# %%
top_customers = (
    df.groupby("Customer Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(top_customers)
# Out:
# Customer Name
# Customer_3446    23881.26
# Customer_7999    22548.01
# Customer_8546    22296.95
# Customer_8097    22001.21
# Customer_5723    21149.97
# Customer_3985    20839.82
# Customer_6785    20391.12
# Customer_7967    19752.49
# Customer_9219    19311.09
# Customer_7026    19251.24
# Name: Sales, dtype: float64

# %%
region_profit = df.groupby("Region")["Profit"].sum()

print(region_profit)
# Out:
# Region
# East     1167939.06
# North    1149482.97
# South    1184024.64
# West     1237833.12
# Name: Profit, dtype: float64

# %%
best_category = (
    df.groupby("Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

print(best_category)
# Out:
# Category
# Furniture          10361856.66
# Office Supplies    10166669.54
# Technology          9954374.74
# Name: Sales, dtype: float64

# %%
total_quantity = df["Quantity"].sum()

print("Total Quantity Sold:", total_quantity)
# Out:
# Total Quantity Sold: 59743

# %%
highest_sale = df.loc[df["Sales"].idxmax()]

print(highest_sale)
# Out:
# Order ID                    ORD07042
# Order Date       2023-11-23 00:00:00
# Customer Name          Customer_6053
# Segment                  Home Office
# Region                          West
# State                 Madhya Pradesh
# Category                   Furniture
# Sub-Category                   Table
# Sales                        4999.51
# Quantity                           8
# Discount                         0.2
# Profit                        953.56
# Month                       November
# Year                            2023
# Name: 7041, dtype: object

# %%
lowest_profit = df.loc[df["Profit"].idxmin()]

print(lowest_profit)
# Out:
# Order ID                    ORD00376
# Order Date       2025-02-10 00:00:00
# Customer Name          Customer_2080
# Segment                  Home Office
# Region                         North
# State                          Delhi
# Category                   Furniture
# Sub-Category                    Desk
# Sales                         109.21
# Quantity                           7
# Discount                         0.2
# Profit                          1.89
# Month                       February
# Year                            2025
# Name: 375, dtype: object

# %%
df["Year"] = df["Order Date"].dt.year

yearly_sales = df.groupby("Year")["Sales"].sum()

print(yearly_sales)
# Out:
# Year
# 2023    12605068.65
# 2024    12228915.65
# 2025     5648916.64
# Name: Sales, dtype: float64

# %%
df["Month"] = df["Order Date"].dt.month_name()

monthly_profit = df.groupby("Month")["Profit"].sum()

print(monthly_profit)
# Out:
# Month
# April        463053.07
# August       340219.03
# December     311348.74
# February     458869.97
# January      486652.09
# July         340944.50
# June         415238.86
# March        493729.45
# May          505448.26
# November     297803.38
# October      318124.80
# September    307847.64
# Name: Profit, dtype: float64

# %%
df.to_csv("dataset/final_sales_data.csv", index=False)

print("Final dataset saved successfully.")
# Out:
# Final dataset saved successfully.
